# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
from scipy import ndimage

# %matplotlib inline

# %% [markdown]
# # Find Boundary

# %%
#filename = "/Volumes/GoogleDrive/My Drive/Alperen's Images/Exp 5 The Best Set/20170616_124815718/images/16062017_125258857_600.jpg"
mypath = "exp5_images/"
filename = mypath+"16062017_125453973_4050.jpg"
# a=io.imread(filename,as_grey=True)
a = cv2.imread(filename)

# %%
# # Plot the image
# plt.figure(figsize=(12,6))
# plt.imshow(a,cmap=plt.cm.gray)
# plt.show()

# plt.figure(figsize=(12,6))
# plt.imshow(a[0:35,:],cmap=plt.cm.gray)
# plt.show()

# plt.figure(figsize=(12,6))
# plt.imshow(a[35:-20,:],cmap=plt.cm.gray)
# plt.show()

# %%
# img = a[35:-20,:]
img = a.copy()
imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(imgray.shape)
# Out:
# (480, 640)

# %%
ret,thresh = cv2.threshold(imgray,5,255,0)
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

print(thresh.shape)

plt.imshow(thresh)
plt.show()

# image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
c = max(contours, key=cv2.contourArea)
# Out:
# (480, 640)

# %%
plt.figure(figsize=(15, 6))
plt.subplot(121)
cv2.drawContours(img, c, -1, (0,255,0), 5)
plt.imshow(img)
plt.subplot(122)
cv2.drawContours(img, contours, -1, (0,255,0), 5)
plt.imshow(img)
plt.show()

# %%
# mask = np.zeros((img.shape[0], img.shape[1], 3))
# for i in c: 
#     mask[i[0][1], i[0][0],:] = np.ones(3)

img = a.copy()
ori = a.copy()
img = cv2.fillPoly(img, pts =[c], color=(255,255,255))
plt.figure(figsize=(15,15))
plt.imshow(a - img)
# plt.imshow(img, cmap = 'Greys')
plt.show()

# %%
# ultra_ori_pos = a - img
# ultra = ultra_ori.copy()
ultra_ori = a - img
ultra = ultra_ori.copy()
ultra = cv2.cvtColor(ultra,cv2.COLOR_BGR2GRAY)

# %%
#normalize ultra
ultra = ultra / (ultra.max() - ultra.min())*255
print(ultra.shape, ultra.max(), ultra.min())

plt.figure(figsize=(10, 10))
plt.imshow(ultra_ori, cmap = 'Greys')
plt.show()
# Out:
# (480, 640) 255.0 0.0

# %% [markdown]
# ## Contour

# %%
image, contours, hierarchy = cv2.findContours(ultra,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
cv2.drawContours(image, contours, -1, (0,255,0), 5)
plt.imshow(image);
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-da4cce415ca4> in <module>
# ----> 1 image, contours, hierarchy = cv2.findContours(ultra,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
#       2 cv2.drawContours(image, contours, -1, (0,255,0), 5)
#       3 plt.imshow(image);
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/contours.cpp:199: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
a = np.zeros([100,100])
plt.imshow(a, cmap='gist_gray');
# Out:
#   File "<ipython-input-13-f1568ad8a6ed>", line 2
#     plt.imshow(a,, cmap='gist_gray');
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Size of Speckle?

# %%
# %matplotlib inline
# ultragray = cv2.cvtColor(ultra, cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(ultra,140,255,0)

# thresh = cv2.erode(thresh, None, iterations=2)
# thresh = cv2.dilate(thresh, None, iterations=2)

plt.figure(figsize=(15,15))
plt.subplot(121)
plt.imshow(thresh, cmap='gist_gray')
plt.subplot(122)
plt.imshow(ultra_ori)
plt.show()

# %%
# ret,thresh = cv2.threshold(imgray,5,255,0)
# ret,thresh = cv2.threshold(ultra,140,255,0)
# thresh = cv2.erode(thresh, None, iterations=2)
# thresh = cv2.dilate(thresh, None, iterations=2)

# print(thresh.shape)

# plt.imshow(thresh)
# plt.show()

# # image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
# image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
# c = max(contours, key=cv2.contourArea)

# print(ultra_ori.shape)
# print(ultra.shape)


ret,thresh = cv2.threshold(ultra_ori,140,255,0)
thresh = cv2.erode(thresh, None, iterations=1)
thresh = cv2.dilate(thresh, None, iterations=1)

edge_detected_image = cv2.Canny(thresh, 75, 200)
plt.figure(figsize=(25,16))
plt.imshow(edge_detected_image, cmap='gist_gray')
# plt.imshow(thresh)

# plt.imshow(ultra_ori)
# plt.imshow(edge_detected_image)

# %%
# for i in np.arange(10, 200, 10):
#     ret,thresh = cv2.threshold(ultra_ori,i,255,0)
#     thresh = cv2.erode(thresh, None, iterations=1)
#     thresh = cv2.dilate(thresh, None, iterations=2)

#     edge_detected_image = cv2.Canny(thresh, 75, 200)
# #     plt.figure()
# #     plt.imshow(edge_detected_image, cmap='gist_gray')
# #     plt.title("i = %i" % i )
# #     plt.show()
    
#     _, contours, _= cv2.findContours(edge_detected_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

#     area = []
#     for c in contours: 
#         a = cv2.contourArea(c)
#         area.append(a)
#     area = np.array(area)
    
#     contours = np.array(contours) 
#     big_contours = contours[(np.where((area >= 20) & (area < 100)))] #(area >= 4) & 
    
#     cp = ultra_ori.copy()
#     plt.figure()
#     cv2.drawContours(cp, big_contours,  -1, (0,255,0), 1)
#     plt.imshow(cp)
#     plt.title("i = %i" % i )
#     plt.show()

# %%
_, contours, _= cv2.findContours(edge_detected_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

area = []
for c in contours: 
    a = cv2.contourArea(c)
    area.append(a)
area = np.array(area)
print(area.min(), area.max(), area.mean())
contours = np.array(contours) 
big_contours = contours[(np.where((area >= 20) & (area < 70)))] #(area >= 4) & 
print(len(big_contours))

cp = ultra_ori.copy()
plt.figure(figsize=(15,15))
cv2.drawContours(cp, big_contours,  -1, (0,255,0), 1)
plt.imshow(cp)
plt.show()
# Out:
# 0.0 212.5 11.225978647686834
# 32
